# %% [markdown]
# # S3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

db1_1 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040001_230911-15/230913/S3/30m-rain/Rx_OBU_CKCOX23040001_20230913-16-53-16_20230913-16-56-58_222secs.csv")
db1_2 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040001_230911-15/230913/S3/30m-rain/Rx_OBU_CKCOX23040001_20230913-16-58-50_20230913-17-17-20_1110secs.csv")
db1_3 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040001_230911-15/230913/S3/50m-rain/Rx_OBU_CKCOX23040001_20230913-17-21-33_20230913-17-31-24_591secs.csv")
db1_4 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040001_230911-15/230913/S3/100m-rain/Rx_OBU_CKCOX23040001_20230913-17-34-39_20230913-17-44-10_571secs.csv")
db1_5 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040001_230911-15/230913/S3/150m/21호0139앞/Rx_OBU_CKCOX23040001_20230913-15-54-07_20230913-16-04-12_605secs.csv")
db1_6 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040001_230911-15/230913/S3/50m-wave on/Rx_OBU_CKCOX23040001_20230913-14-43-44_20230913-14-53-19_575secs.csv")
db1_7 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040001_230911-15/230913/S3/100m-wave on/Rx_OBU_CKCOX23040001_20230913-15-11-43_20230913-15-21-35_592secs.csv")
db1_8 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040001_230911-15/230913/S3/150m/21호0138앞-wave on/Rx_OBU_CKCOX23040001_20230913-15-37-22_20230913-15-41-58_276secs.csv")
db1_9 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040001_230911-15/230913/S3/150m/21호0138앞-wave on/Rx_OBU_CKCOX23040001_20230913-15-43-29_20230913-15-48-10_281secs.csv")

db2_1 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040002_230911-15/230913/S3/30m-rain/Rx_OBU_CKCOX23040002_20230913-16-53-18_20230913-16-57-11_233secs.csv")
db2_2 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040002_230911-15/230913/S3/30m-rain/Rx_OBU_CKCOX23040002_20230913-16-58-51_20230913-17-17-19_1108secs.csv")
db2_3 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040002_230911-15/230913/S3/50m-rain/Rx_OBU_CKCOX23040002_20230913-17-21-33_20230913-17-31-24_591secs.csv")
db2_4 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040002_230911-15/230913/S3/100m-rain/Rx_OBU_CKCOX23040002_20230913-17-34-41_20230913-17-44-09_568secs.csv")
db2_5 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040002_230911-15/230913/S3/150m/0139선두/Rx_OBU_CKCOX23040002_20230913-15-54-07_20230913-16-04-12_605secs.csv")
db2_6 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040002_230911-15/230913/S3/50m-wave on/Rx_OBU_CKCOX23040002_20230913-14-43-49_20230913-14-53-20_571secs.csv")
db2_7 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040002_230911-15/230913/S3/100m-wave on/Rx_OBU_CKCOX23040002_20230913-15-11-44_20230913-15-21-36_592secs.csv")
db2_8 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040002_230911-15/230913/S3/150m/0138선두-wave on/Rx_OBU_CKCOX23040002_20230913-15-37-22_20230913-15-42-09_287secs.csv")
db2_9 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040002_230911-15/230913/S3/150m/0138선두-wave on/Rx_OBU_CKCOX23040002_20230913-15-43-30_20230913-15-48-13_283secs.csv")

db1 = pd.concat([db1_1, db1_2, db1_3, db1_4, db1_5, db1_6, db1_7, db1_8, db1_9])
db2 = pd.concat([db2_1, db2_2, db2_3, db2_4, db2_5, db2_6, db2_7, db2_8, db2_9])

# 필요한 열 추출
db1 = db1[['unTxVehicleSpeed', 'usCommDistance', 'unPdr(percent)']]
db2 = db2[['unTxVehicleSpeed', 'usCommDistance', 'unPdr(percent)']]

# %%
#숫자로 변경
db1['unPdr(percent)'] = pd.to_numeric(db1['unPdr(percent)'], errors='coerce')
db1['usCommDistance'] = pd.to_numeric(db1['usCommDistance'], errors='coerce')
db1['unTxVehicleSpeed'] = pd.to_numeric(db1['unTxVehicleSpeed'], errors='coerce')
db2['unPdr(percent)'] = pd.to_numeric(db2['unPdr(percent)'], errors='coerce')
db2['usCommDistance'] = pd.to_numeric(db2['usCommDistance'], errors='coerce')
db2['unTxVehicleSpeed'] = pd.to_numeric(db2['unTxVehicleSpeed'], errors='coerce')

# 삭제하기 전 데이터 개수 출력
original_db1_count = len(db1)
original_db2_count = len(db2)

# 누락된 행 삭제
db1 = db1.dropna(subset=['unPdr(percent)'])
db1 = db1.dropna(subset=['usCommDistance'])
db1 = db1.dropna(subset=['unTxVehicleSpeed'])
db2 = db2.dropna(subset=['unPdr(percent)'])
db2 = db2.dropna(subset=['usCommDistance'])
db2 = db2.dropna(subset=['unTxVehicleSpeed'])

# 삭제한 행의 수 계산
delete_db1_count = original_db1_count - len(db1)
delete_db2_count = original_db2_count - len(db2)

# 삭제한 행의 수 출력
print(f"CKCOX32040001파일에서 삭제한 행의 수: {delete_db1_count}")
print(f"CKCOX32040002파일에서 삭제한 행의 수: {delete_db2_count}")
# Out:
# CKCOX32040001파일에서 삭제한 행의 수: 0
# CKCOX32040002파일에서 삭제한 행의 수: 10

# %%
# usCommDistance 오름차순으로 출력
db1.sort_values('unTxVehicleSpeed')
# Out:
#       unTxVehicleSpeed  usCommDistance  unPdr(percent)
# 0                   40        8.989093          100.00
# 6633                40       31.960805           99.96
# 6634                40       31.270251           99.96
# 6635                40       31.854936           99.96
# 6636                40       33.407559           99.96
# ...                ...             ...             ...
# 3915               100       74.395500           76.42
# 3914               100       74.330873           76.42
# 3913               100       73.525940           76.41
# 3939               100       86.105361           76.53
# 2146               100       15.155748           76.89
#
# [42358 rows x 3 columns]

# %%
db2.sort_values('unTxVehicleSpeed')
# Out:
#       unTxVehicleSpeed  usCommDistance  unPdr(percent)
# 2                 40.0        9.153512          100.00
# 7081              40.0       30.828581           99.77
# 7082              40.0       31.088213           99.77
# 7083              40.0       29.874127           99.77
# 7084              40.0       29.942977           99.77
# ...                ...             ...             ...
# 2025             100.0       96.205824           64.35
# 2024             100.0       96.336344           64.34
# 2023             100.0       95.918163           64.33
# 2043             100.0       95.552471           64.43
# 860              100.0      151.402147           50.08
#
# [34938 rows x 3 columns]

# %%
# 박스플롯 생성 (이상치 확인)
plt.figure(figsize=(8, 6))
plt.boxplot(db1['unTxVehicleSpeed'])
plt.title('Box Plot of unTxVehicleSpeed_CKCOX23040001')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(db1['usCommDistance'])
plt.title('Box Plot of usCommDistance_CKCOX23040001')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(db1['unPdr(percent)'])
plt.title('Box Plot of unPdr(percent)_CKCOX23040001')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(db2['unTxVehicleSpeed'])
plt.title('Box Plot of unTxVehicleSpeed_CKCOX23040002')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(db2['usCommDistance'])
plt.title('Box Plot of usCommDistance_CKCOX23040002')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(db2['unPdr(percent)'])
plt.title('Box Plot of unPdr(percent)_CKCOX23040002')
plt.show()

# %%
# 이상치 대체 (3표준편차 : 약 99.7%정도)
mean_db1_value = db1['usCommDistance'].mean()
std_db1_dev = db1['usCommDistance'].std()
dev3_db1 = 3 * std_db1_dev
mean_db2_value = db2['usCommDistance'].mean()
std_db2_dev = db2['usCommDistance'].std()
dev3_db2 = 3 * std_db2_dev

# 이상치를 평균값으로 대체하고 대체한 이상치의 수를 계산
outlier_db1_count = sum(abs(db1['usCommDistance'] - mean_db1_value) > dev3_db1)
db1['usCommDistance'] = db1['usCommDistance'].where(abs(db1['usCommDistance'] - mean_db1_value) <= dev3_db1, mean_db1_value)
outlier_db2_count = sum(abs(db2['usCommDistance'] - mean_db2_value) > dev3_db2)
db2['usCommDistance'] = db2['usCommDistance'].where(abs(db2['usCommDistance'] - mean_db2_value) <= dev3_db2, mean_db2_value)

# 대체한 이상치 횟수 출력
print(f"대체한 이상치의 수: {outlier_db1_count}")
print(f"대체한 이상치의 수: {outlier_db2_count}")

# 박스 플롯 그리기
plt.figure(figsize=(8, 6))
plt.boxplot(db1['usCommDistance'])
plt.title('Box Plot of usCommDistance_CKCOX23040001 (replace outlier)')
plt.show()
plt.figure(figsize=(8, 6))
plt.boxplot(db2['usCommDistance'])
plt.title('Box Plot of usCommDistance_CKCOX23040002 (replace outlier)')
plt.show()
# Out:
# 대체한 이상치의 수: 264
# 대체한 이상치의 수: 227

# %%
# usCommDistance 오름차순으로 출력
db1.sort_values('usCommDistance')
# Out:
#      unTxVehicleSpeed  usCommDistance  unPdr(percent)
# 50                100        1.162238          100.00
# 49                100        1.162238          100.00
# 53                100        1.172299          100.00
# 55                100        1.177544          100.00
# 54                100        1.177544          100.00
# ..                ...             ...             ...
# 859               100      296.178787           74.65
# 852               100      296.312827           74.56
# 860               100      296.375618           74.61
# 856               100      296.615694           74.65
# 854               100      296.808064           74.60
#
# [42358 rows x 3 columns]

# %%
db2.sort_values('usCommDistance')
# Out:
#      unTxVehicleSpeed  usCommDistance  unPdr(percent)
# 59              100.0        1.485728          100.00
# 60              100.0        1.485728          100.00
# 65              100.0        1.700132          100.00
# 64              100.0        1.784058          100.00
# 58              100.0        1.924821          100.00
# ..                ...             ...             ...
# 692             100.0      244.598187           54.59
# 691             100.0      248.222542           54.68
# 690             100.0      261.835919           55.40
# 689             100.0      284.638504           57.02
# 688             100.0      285.979501           57.03
#
# [34938 rows x 3 columns]

# %%
# 데이터 그룹화 및 평균 계산
db1_group = db1.groupby('usCommDistance')['unPdr(percent)'].mean().reset_index()
db2_group = db2.groupby('usCommDistance')['unPdr(percent)'].mean().reset_index()

# 그래프 그리기 (거리별 PDR)
plt.figure(figsize=(10, 6))
plt.plot(db1_group['usCommDistance'], db1_group['unPdr(percent)'], label='CKCOX23040001', marker='o')
plt.plot(db2_group['usCommDistance'], db2_group['unPdr(percent)'], label='CKCOX23040002', marker='x')
plt.xlabel('Distance (m)')
plt.ylabel('Pdr (%)')
plt.title('PDR by Distance_S3')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 이동 평균 계산
window_size = 100
db1_group['unPdr_M'] = db1_group['unPdr(percent)'].rolling(window=window_size).mean()
db2_group['unPdr_M'] = db2_group['unPdr(percent)'].rolling(window=window_size).mean()

# 그래프 그리기 (거리별 PDR)
plt.figure(figsize=(10, 6))
plt.plot(db1_group['usCommDistance'], db1_group['unPdr_M'], label='CKCOX23040001 (Smoothed)', marker='o')
plt.plot(db2_group['usCommDistance'], db2_group['unPdr_M'], label='CKCOX23040002 (Smoothed)', marker='x')
plt.xlabel('Distance (m)')
plt.ylabel('Smoothed Pdr (%)')
plt.title('PDR by Distance_S3 (smoothed)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 데이터 그룹화 및 평균 계산
db1_group = db1.groupby('unTxVehicleSpeed')['unPdr(percent)'].mean().reset_index()
db2_group = db2.groupby('unTxVehicleSpeed')['unPdr(percent)'].mean().reset_index()

# 그래프 그리기 (속도별 PDR)
plt.figure(figsize=(10, 6))
plt.plot(db1_group['unTxVehicleSpeed'], db1_group['unPdr(percent)'], label='CKCOX23040001', marker='o')
plt.plot(db2_group['unTxVehicleSpeed'], db2_group['unPdr(percent)'], label='CKCOX23040002', marker='x')
plt.xlabel('Speed (km/h)')
plt.ylabel('Pdr (%)')
plt.title('PDR by Speed')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 히트맵 생성 (상관관계 파악)
plt.figure(figsize=(10,6))
sns.heatmap(data = db1.corr(), annot=True, fmt='.2f', linewidths=.5, cmap='Blues')
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data = db2.corr(), annot=True, fmt='.2f', linewidths=.5, cmap='Oranges')
# Out:
# <Axes: >
