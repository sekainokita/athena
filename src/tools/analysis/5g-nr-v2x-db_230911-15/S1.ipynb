# %% [markdown]
# # S1

# %% [markdown]
# ### S1, 0138-RSU

# %%
import pandas as pd
import matplotlib.pyplot as plt

db1_1 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040001_230911-15/230914/S1/1-21호0138 RSU/Rx_OBU_CKCOX23040001_20230914-16-03-45_20230914-16-05-55_130secs.csv")
db1_2 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040001_230911-15/230914/S1/2-21호0138 RSU/Rx_OBU_CKCOX23040001_20230914-16-24-34_20230914-16-28-41_247secs.csv")
db1_3 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040001_230911-15/230914/S1/3-21호0138 RSU/Rx_OBU_CKCOX23040001_20230914-16-40-41_20230914-16-47-33_412secs.csv")
db1_4 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040001_230911-15/230914/S1/4-21호0138 RSU/Rx_OBU_CKCOX23040001_20230914-16-58-35_20230914-17-06-12_457secs.csv")

db2_1 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040002_230911-15/230914/S1/50m이내/21호0138-RSU/Rx_OBU_CKCOX23040002_20230914-16-03-45_20230914-16-05-56_131secs.csv")
db2_2 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040002_230911-15/230914/S1/100m이내/21호0138-RSU/Rx_OBU_CKCOX23040002_20230914-16-24-35_20230914-16-28-42_247secs.csv")
db2_3 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040002_230911-15/230914/S1/150m이내/21호0138-RSU/Rx_OBU_CKCOX23040002_20230914-16-40-41_20230914-16-47-35_414secs.csv")
db2_4 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040002_230911-15/230914/S1/200m/21호0138-RSU/Rx_OBU_CKCOX23040002_20230914-16-58-34_20230914-17-06-11_457secs.csv")

db1 = pd.concat([db1_1, db1_2, db1_3, db1_4])
db2 = pd.concat([db2_1, db2_2, db2_3, db2_4])

# 필요한 열 추출
db1 = db1[['usCommDistance', 'unPdr(percent)']]
db2 = db2[['usCommDistance', 'unPdr(percent)']]

# %%
#숫자로 변경
db1['unPdr(percent)'] = pd.to_numeric(db1['unPdr(percent)'], errors='coerce')
db1['usCommDistance'] = pd.to_numeric(db1['usCommDistance'], errors='coerce')
db2['unPdr(percent)'] = pd.to_numeric(db2['unPdr(percent)'], errors='coerce')
db2['usCommDistance'] = pd.to_numeric(db2['usCommDistance'], errors='coerce')

# 삭제하기 전 데이터 개수 출력
original_db1_count = len(db1)
original_db2_count = len(db2)

# 누락된 행 삭제
db1 = db1.dropna(subset=['unPdr(percent)'])
db1 = db1.dropna(subset=['usCommDistance'])
db2 = db2.dropna(subset=['unPdr(percent)'])
db2 = db2.dropna(subset=['usCommDistance'])

# 삭제한 행의 수 계산
delete_db1_count = original_db1_count - len(db1)
delete_db2_count = original_db2_count - len(db2)

# 삭제한 행의 수 출력
print(f"CKCOX32040001파일에서 삭제한 행의 수: {delete_db1_count}")
print(f"CKCOX32040002파일에서 삭제한 행의 수: {delete_db2_count}")
# Out:
# CKCOX32040001파일에서 삭제한 행의 수: 0
# CKCOX32040002파일에서 삭제한 행의 수: 1

# %%
# usCommDistance 오름차순으로 출력
db1.sort_values('usCommDistance')
# Out:
#      usCommDistance  unPdr(percent)
# 86         0.316319           95.60
# 87         0.316319           95.65
# 88         0.663468           95.69
# 89         1.067053           95.74
# 90         1.481654           95.78
# ..              ...             ...
# 469      346.594764           94.37
# 338      347.190991           43.29
# 470      350.288696           94.20
# 471      351.758812           94.21
# 472      353.230243           94.22
#
# [7610 rows x 2 columns]

# %%
db2.sort_values('usCommDistance')
# Out:
#     usCommDistance  unPdr(percent)
# 95        0.316319           96.96
# 96        0.358068           97.00
# 97        0.741824           97.02
# 98        0.741824           97.05
# 90        1.353859           96.80
# ..             ...             ...
# 4      4294.967295            0.61
# 3      4294.967295            0.49
# 2      4294.967295            0.36
# 1      4294.967295            0.24
# 0      4294.967295            0.12
#
# [6320 rows x 2 columns]

# %%
# 박스플롯 생성 (이상치 확인)
plt.figure(figsize=(8, 6))
plt.boxplot(db1['usCommDistance'])
plt.title('Box Plot of usCommDistance_CKCOX23040001')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(db1['unPdr(percent)'])
plt.title('Box Plot of unPdr(percent)_CKCOX23040001')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(db2['usCommDistance'])
plt.title('Box Plot of usCommDistance_CKCOX23040002')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(db2['unPdr(percent)'])
plt.title('Box Plot of unPdr(percent)_CKCOX23040002')
plt.show()

# %%
# 이상치 대체 (3표준편차 : 약 99.7%정도)
mean_db1_value = db1['usCommDistance'].mean()
std_db1_dev = db1['usCommDistance'].std()
dev3_db1 = 3 * std_db1_dev
mean_db2_value = db2['usCommDistance'].mean()
std_db2_dev = db2['usCommDistance'].std()
dev3_db2 = 3 * std_db2_dev

# 이상치를 평균값으로 대체하고 대체한 이상치의 수를 계산
outlier_db1_count = sum(abs(db1['usCommDistance'] - mean_db1_value) > dev3_db1)
db1['usCommDistance'] = db1['usCommDistance'].where(abs(db1['usCommDistance'] - mean_db1_value) <= dev3_db1, mean_db1_value)
outlier_db2_count = sum(abs(db2['usCommDistance'] - mean_db2_value) > dev3_db2)
db2['usCommDistance'] = db2['usCommDistance'].where(abs(db2['usCommDistance'] - mean_db2_value) <= dev3_db2, mean_db2_value)

# 대체한 이상치 횟수 출력
print(f"대체한 이상치의 수: {outlier_db1_count}")
print(f"대체한 이상치의 수: {outlier_db2_count}")

# 박스 플롯 그리기
plt.figure(figsize=(8, 6))
plt.boxplot(db1['usCommDistance'])
plt.title('Box Plot of usCommDistance_CKCOX23040001 (replace outlier)')
plt.show()
plt.figure(figsize=(8, 6))
plt.boxplot(db2['usCommDistance'])
plt.title('Box Plot of usCommDistance_CKCOX23040002 (replace outlier)')
plt.show()
# Out:
# 대체한 이상치의 수: 96
# 대체한 이상치의 수: 8

# %%
# usCommDistance 오름차순으로 출력
db1.sort_values('usCommDistance')
# Out:
#      usCommDistance  unPdr(percent)
# 87         0.316319           95.65
# 86         0.316319           95.60
# 88         0.663468           95.69
# 89         1.067053           95.74
# 90         1.481654           95.78
# ..              ...             ...
# 308      314.751200           73.57
# 306      314.751200           73.44
# 305      314.751200           73.38
# 304      314.751200           73.31
# 307      314.751200           73.50
#
# [7610 rows x 2 columns]

# %%
db2.sort_values('usCommDistance')
# Out:
#      usCommDistance  unPdr(percent)
# 95         0.316319           96.96
# 96         0.358068           97.00
# 97         0.741824           97.02
# 98         0.741824           97.05
# 94         1.353859           96.93
# ..              ...             ...
# 455      347.994449           90.11
# 456      349.134086           90.13
# 457      350.672361           90.15
# 458      353.014893           90.17
# 459      354.190075           90.19
#
# [6320 rows x 2 columns]

# %%
# 데이터 그룹화 및 평균 계산
db1_group = db1.groupby('usCommDistance')['unPdr(percent)'].mean().reset_index()
db2_group = db2.groupby('usCommDistance')['unPdr(percent)'].mean().reset_index()

# 그래프 그리기 (거리별 PDR)
plt.figure(figsize=(10, 6))
plt.plot(db1_group['usCommDistance'], db1_group['unPdr(percent)'], label='CKCOX23040001', marker='o')
plt.plot(db2_group['usCommDistance'], db2_group['unPdr(percent)'], label='CKCOX23040002', marker='x')
plt.xlabel('Distance (m)')
plt.ylabel('Pdr (%)')
plt.title('PDR by Distance_S1')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 이동 평균 계산
window_size = 500
db1_group['unPdr_M'] = db1_group['unPdr(percent)'].rolling(window=window_size).mean()
db2_group['unPdr_M'] = db2_group['unPdr(percent)'].rolling(window=window_size).mean()

# 그래프 그리기 (거리별 PDR)
plt.figure(figsize=(10, 6))
plt.plot(db1_group['usCommDistance'], db1_group['unPdr_M'], label='CKCOX23040001 (Smoothed)', marker='o')
plt.plot(db2_group['usCommDistance'], db2_group['unPdr_M'], label='CKCOX23040002 (Smoothed)', marker='x')
plt.xlabel('Distance (m)')
plt.ylabel('Smoothed Pdr (%)')
plt.title('PDR by Distance_S1 (smoothed)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### S1, 0139-RSU

# %%
import pandas as pd
import matplotlib.pyplot as plt

db1_1 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040001_230911-15/230914/S1/1-21호0139 RSU/Rx_OBU_CKCOX23040001_20230914-15-58-02_20230914-16-00-52_170secs.csv")
db1_2 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040001_230911-15/230914/S1/2-21호0139 RSU/Rx_OBU_CKCOX23040001_20230914-16-16-15_20230914-16-20-06_231secs.csv")
db1_3 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040001_230911-15/230914/S1/3-21호0139 RSU/Rx_OBU_CKCOX23040001_20230914-16-31-37_20230914-16-38-43_426secs.csv")
db1_4 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040001_230911-15/230914/S1/4-21호0139 RSU/Rx_OBU_CKCOX23040001_20230914-16-50-54_20230914-16-57-07_373secs.csv")

db2_1 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040002_230911-15/230914/S1/50m이내/21호0139-RSU/Rx_OBU_CKCOX23040002_20230914-15-58-04_20230914-16-00-53_169secs.csv")
db2_2 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040002_230911-15/230914/S1/100m이내/21호0139-RSU/Rx_OBU_CKCOX23040002_20230914-16-16-15_20230914-16-20-04_229secs.csv")
db2_3 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040002_230911-15/230914/S1/150m이내/21호0139-RSU/Rx_OBU_CKCOX23040002_20230914-16-31-36_20230914-16-38-40_424secs.csv")
db2_4 = pd.read_csv("C:/Users/KETI2023/Desktop/Tx-Rx 실험/대구/5g-nr-v2x-db_CKCOX23040002_230911-15/230914/S1/200m/21호0139-RSU/Rx_OBU_CKCOX23040002_20230914-16-50-55_20230914-16-57-07_372secs.csv")

db1 = pd.concat([db1_1, db1_2, db1_3, db1_4])
db2 = pd.concat([db2_1, db2_2, db2_3, db2_4])

# 필요한 열 추출
db1 = db1[['usCommDistance', 'unPdr(percent)']]
db2 = db2[['usCommDistance', 'unPdr(percent)']]

# %%
#숫자로 변경
db1['unPdr(percent)'] = pd.to_numeric(db1['unPdr(percent)'], errors='coerce')
db1['usCommDistance'] = pd.to_numeric(db1['usCommDistance'], errors='coerce')
db2['unPdr(percent)'] = pd.to_numeric(db2['unPdr(percent)'], errors='coerce')
db2['usCommDistance'] = pd.to_numeric(db2['usCommDistance'], errors='coerce')

# 삭제하기 전 데이터 개수 출력
original_db1_count = len(db1)
original_db2_count = len(db2)

# 누락된 행 삭제
db1 = db1.dropna(subset=['unPdr(percent)'])
db1 = db1.dropna(subset=['usCommDistance'])
db2 = db2.dropna(subset=['unPdr(percent)'])
db2 = db2.dropna(subset=['usCommDistance'])

# 삭제한 행의 수 계산
delete_db1_count = original_db1_count - len(db1)
delete_db2_count = original_db2_count - len(db2)

# 삭제한 행의 수 출력
print(f"CKCOX32040001파일에서 삭제한 행의 수: {delete_db1_count}")
print(f"CKCOX32040002파일에서 삭제한 행의 수: {delete_db2_count}")
# Out:
# CKCOX32040001파일에서 삭제한 행의 수: 0
# CKCOX32040002파일에서 삭제한 행의 수: 0

# %%
# usCommDistance 오름차순으로 출력
db1.sort_values('usCommDistance')
# Out:
#       usCommDistance  unPdr(percent)
# 795         3.041454           82.40
# 2787        3.041454           66.85
# 2786        3.041454           66.85
# 2041        3.041454           79.79
# 1436        3.074728           81.32
# ...              ...             ...
# 251       314.673153           67.74
# 252       324.299731           65.20
# 253       343.841383           60.62
# 255       372.882333           54.35
# 254       380.866624           54.37
#
# [7333 rows x 2 columns]

# %%
db2.sort_values('usCommDistance')
# Out:
#       usCommDistance  unPdr(percent)
# 1291        3.256838           95.13
# 1288        3.379348           73.23
# 2989        3.379348           71.77
# 2392        3.379348           71.32
# 2988        3.379348           71.76
# ...              ...             ...
# 188       296.380213           57.44
# 189       303.881491           54.59
# 190       305.459163           54.26
# 191       319.327639           49.74
# 192       319.738638           49.87
#
# [6559 rows x 2 columns]

# %%
# 박스플롯 생성 (이상치 확인)
plt.figure(figsize=(8, 6))
plt.boxplot(db1['usCommDistance'])
plt.title('Box Plot of usCommDistance_CKCOX23040001')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(db1['unPdr(percent)'])
plt.title('Box Plot of unPdr(percent)_CKCOX23040001')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(db2['usCommDistance'])
plt.title('Box Plot of usCommDistance_CKCOX23040002')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot(db2['unPdr(percent)'])
plt.title('Box Plot of unPdr(percent)_CKCOX23040002')
plt.show()

# %%
# 이상치 대체 (3표준편차 : 약 99.7%정도)
mean_db1_value = db1['usCommDistance'].mean()
std_db1_dev = db1['usCommDistance'].std()
std3_db1 = 3 * std_db1_dev
mean_db2_value = db2['usCommDistance'].mean()
std_db2_dev = db2['usCommDistance'].std()
std3_db2 = 3 * std_db2_dev

# 이상치를 평균값으로 대체하고 대체한 이상치의 수를 계산
outlier_db1_count = sum(abs(db1['usCommDistance'] - mean_db1_value) > std3_db1)
db1['usCommDistance'] = db1['usCommDistance'].where(abs(db1['usCommDistance'] - mean_db1_value) <= std3_db1, mean_db1_value)
outlier_db2_count = sum(abs(db2['usCommDistance'] - mean_db2_value) > std3_db2)
db2['usCommDistance'] = db2['usCommDistance'].where(abs(db2['usCommDistance'] - mean_db2_value) <= std3_db2, mean_db2_value)

# 대체한 이상치 횟수 출력
print(f"대체한 이상치의 수: {outlier_db1_count}")
print(f"대체한 이상치의 수: {outlier_db2_count}")

# 박스 플롯 그리기
plt.figure(figsize=(8, 6))
plt.boxplot(db1['usCommDistance'])
plt.title('Box Plot of usCommDistance_CKCOX23040001 (replace outlier)')
plt.show()
plt.figure(figsize=(8, 6))
plt.boxplot(db2['usCommDistance'])
plt.title('Box Plot of usCommDistance_CKCOX23040002 (replace outlier)')
plt.show()
# Out:
# 대체한 이상치의 수: 62
# 대체한 이상치의 수: 49

# %%
# usCommDistance 오름차순으로 출력
db1.sort_values('usCommDistance')
# Out:
#       usCommDistance  unPdr(percent)
# 795         3.041454           82.40
# 2787        3.041454           66.85
# 2786        3.041454           66.85
# 2041        3.041454           79.79
# 1436        3.074728           81.32
# ...              ...             ...
# 189       263.395954           76.00
# 190       263.584399           76.09
# 191       264.459313           76.19
# 192       265.740176           75.68
# 193       265.740176           75.78
#
# [7333 rows x 2 columns]

# %%
db2.sort_values('usCommDistance')
# Out:
#       usCommDistance  unPdr(percent)
# 1291        3.256838           95.13
# 730         3.379348           76.14
# 1288        3.379348           73.23
# 2988        3.379348           71.76
# 2392        3.379348           71.32
# ...              ...             ...
# 139       254.898934           58.57
# 140       255.311208           58.74
# 141       255.828019           58.92
# 142       256.240896           59.09
# 143       257.180917           59.01
#
# [6559 rows x 2 columns]

# %%
# 데이터 그룹화 및 평균 계산
db1_group = db1.groupby('usCommDistance')['unPdr(percent)'].mean().reset_index()
db2_group = db2.groupby('usCommDistance')['unPdr(percent)'].mean().reset_index()

# 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(db1_group['usCommDistance'], db1_group['unPdr(percent)'], label='CKCOX23040001', marker='o')
plt.plot(db2_group['usCommDistance'], db2_group['unPdr(percent)'], label='CKCOX23040002', marker='x')
plt.xlabel('Distance (m)')
plt.ylabel('Pdr (%)')
plt.title('PDR by Distance_S1')
plt.legend()
plt.grid(True)
plt.show()

# %%
# 이동 평균 계산
window_size = 500
db1_group['unPdr_M'] = db1_group['unPdr(percent)'].rolling(window=window_size).mean()
db2_group['unPdr_M'] = db2_group['unPdr(percent)'].rolling(window=window_size).mean()

# 그래프 그리기
plt.figure(figsize=(10, 6))
plt.plot(db1_group['usCommDistance'], db1_group['unPdr_M'], label='CKCOX23040001 (Smoothed)', marker='o')
plt.plot(db2_group['usCommDistance'], db2_group['unPdr_M'], label='CKCOX23040002 (Smoothed)', marker='x')
plt.xlabel('Distance (m)')
plt.ylabel('Smoothed Pdr (%)')
plt.title('PDR by Distance_S1 (smoothed)')
plt.legend()
plt.grid(True)
plt.show()
